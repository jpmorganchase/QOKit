# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import qokit.maxcut as mc
from QAOA_simulator import get_overlap, get_simulator
import QAOA_proxy as qp
import QAOA_paper_proxy as qpp

# QAOAの層数
p = 1

# 結果を格納するリスト
success_probs_new_proxy = []
success_probs_paper_proxy = []

# Nを5から9まで変化させて計算
for N in range(3, 10):
    # エルデシュ・レーニイグラフの生成（ノード数N、エッジの確率0.5）
    G = nx.erdos_renyi_graph(N, 0.5)

    # グラフからIsingモデルの項を取得
    ising_model = mc.get_maxcut_terms(G)

    # シミュレーターの初期化
    sim = get_simulator(N, ising_model)

    # 初期のgammaとbetaを設定（全て0.1）
    init_gamma, init_beta = np.full((2, p), 0.1)

    # QAOAプロキシを使ってQAOAの実行（結果としてgammaとbetaを取得）
    result = qp.QAOA_proxy_run(G.number_of_edges(), N, p, init_gamma, init_beta)
    gamma = result["gamma"]
    beta = result["beta"]

    # 得られたgammaとbetaでオーバーラップを計算
    overlap = get_overlap(N, ising_model, gamma, beta, simulator_name='auto')

    # 成功確率（オーバーラップ）を計算
    success_prob = overlap

    # 結果をリストに追加
    success_probs_new_proxy.append(success_prob)

for N in range(3, 10):
    # エルデシュ・レーニイグラフの生成（ノード数N、エッジの確率0.5）
    G = nx.erdos_renyi_graph(N, 0.5)

    # グラフからIsingモデルの項を取得
    ising_model = mc.get_maxcut_terms(G)

    # シミュレーターの初期化
    sim = get_simulator(N, ising_model)

    # 初期のgammaとbetaを設定（全て0.1）
    init_gamma, init_beta = np.full((2, p), 0.1)

    # QAOAプロキシを使ってQAOAの実行（結果としてgammaとbetaを取得）
    result = qpp.QAOA_paper_proxy_run(G.number_of_edges(), N, p, init_gamma, init_beta)
    gamma = result["gamma"]
    beta = result["beta"]

    # 得られたgammaとbetaでオーバーラップを計算
    overlap = get_overlap(N, ising_model, gamma, beta, simulator_name='auto')

    # 成功確率（オーバーラップ）を計算
    success_prob = overlap

    # 結果をリストに追加
    success_probs_paper_proxy.append(success_prob)

# 棒グラフの作成
bar_width = 0.35  # バーの幅
index = np.arange(3, 10)  # x軸のインデックス

# 新しいプロキシの棒グラフ
plt.bar(index, success_probs_new_proxy, bar_width, color='red', alpha=0.7, label='New Proxy')

# 論文プロキシの棒グラフ
plt.bar(index + bar_width, success_probs_paper_proxy, bar_width, color='blue', alpha=0.7, label='Paper Proxy')

# グラフの設定
plt.xlabel('Number of Nodes (N)')
plt.ylabel('Success Probability')
plt.title(f'Success Probability vs Number of Nodes (N) (P={p})')
plt.xticks(index + bar_width / 2, index)  # x軸の目盛りを設定
plt.legend()

# グラフの表示
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import qokit.maxcut as mc
from QAOA_simulator import get_overlap, get_simulator
import QAOA_proxy as qp
import QAOA_paper_proxy as qpp

# QAOAの層数
p = 5

# 結果を格納するリスト
success_probs_new_proxy = []
success_probs_paper_proxy = []

# Nを5から9まで変化させて計算
for N in range(3, 10):
    # エルデシュ・レーニイグラフの生成（ノード数N、エッジの確率0.5）
    G = nx.erdos_renyi_graph(N, 0.5)

    # グラフからIsingモデルの項を取得
    ising_model = mc.get_maxcut_terms(G)

    # シミュレーターの初期化
    sim = get_simulator(N, ising_model)

    # 初期のgammaとbetaを設定（全て0.1）
    init_gamma, init_beta = np.full((2, p), 0.1)

    # QAOAプロキシを使ってQAOAの実行（結果としてgammaとbetaを取得）
    result = qp.QAOA_proxy_run(G.number_of_edges(), N, p, init_gamma, init_beta)
    gamma = result["gamma"]
    beta = result["beta"]

    # 得られたgammaとbetaでオーバーラップを計算
    overlap = get_overlap(N, ising_model, gamma, beta, simulator_name='auto')

    # 成功確率（オーバーラップ）を計算
    success_prob = overlap

    # 結果をリストに追加
    success_probs_new_proxy.append(success_prob)

for N in range(3, 10):
    # エルデシュ・レーニイグラフの生成（ノード数N、エッジの確率0.5）
    G = nx.erdos_renyi_graph(N, 0.5)

    # グラフからIsingモデルの項を取得
    ising_model = mc.get_maxcut_terms(G)

    # シミュレーターの初期化
    sim = get_simulator(N, ising_model)

    # 初期のgammaとbetaを設定（全て0.1）
    init_gamma, init_beta = np.full((2, p), 0.1)

    # QAOAプロキシを使ってQAOAの実行（結果としてgammaとbetaを取得）
    result = qpp.QAOA_paper_proxy_run(G.number_of_edges(), N, p, init_gamma, init_beta)
    gamma = result["gamma"]
    beta = result["beta"]

    # 得られたgammaとbetaでオーバーラップを計算
    overlap = get_overlap(N, ising_model, gamma, beta, simulator_name='auto')

    # 成功確率（オーバーラップ）を計算
    success_prob = overlap

    # 結果をリストに追加
    success_probs_paper_proxy.append(success_prob)

# 棒グラフの作成
bar_width = 0.35  # バーの幅
index = np.arange(3, 10)  # x軸のインデックス

# 新しいプロキシの棒グラフ
plt.bar(index, success_probs_new_proxy, bar_width, color='red', alpha=0.7, label='New Proxy')

# 論文プロキシの棒グラフ
plt.bar(index + bar_width, success_probs_paper_proxy, bar_width, color='blue', alpha=0.7, label='Paper Proxy')

# グラフの設定
plt.xlabel('Number of Nodes (N)')
plt.ylabel('Success Probability')
plt.title(f'Success Probability vs Number of Nodes (N) (P={p})')
plt.xticks(index + bar_width / 2, index)  # x軸の目盛りを設定
plt.legend()

# グラフの表示
plt.show()
# Out:
# capi_return is NULL
# Call-back cb_calcfc_in__cobyla__user__routines failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 58
#      55 init_gamma, init_beta = np.full((2, p), 0.1)
#      57 # QAOAプロキシを使ってQAOAの実行（結果としてgammaとbetaを取得）
# ---> 58 result = qpp.QAOA_paper_proxy_run(G.number_of_edges(), N, p, init_gamma, init_beta)
#      59 gamma = result["gamma"]
#      60 beta = result["beta"]
#
# File ~/dev/QOKit/grips/QAOA_paper_proxy.py:111, in QAOA_paper_proxy_run(num_constraints, num_qubits, p, init_gamma, init_beta, optimizer_method, optimizer_options, expectations)
#     108 init_freq = np.hstack([init_gamma, init_beta])
#     110 start_time = time.time()
# --> 111 result = scipy.optimize.minimize(
#     112     inverse_paper_proxy_objective_function(num_constraints, num_qubits, p, expectations),
#     113     init_freq,
#     114     args=(),
#     115     method=optimizer_method,
#     116     options=optimizer_options,
#     117 )
#     118 # the above returns a scipy optimization result object that has multiple attributes
#     119 # result.x gives the optimal solutionsol.success #bool whether algorithm succeeded
#     120 # result.message #message of why algorithms terminated
#     121 # result.nfev is number of iterations used (here, number of QAOA calls)
#     122 end_time = time.time()
#
# File ~/dev/qokit/lib/python3.10/site-packages/scipy/optimize/_minimize.py:737, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     734     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     735                         **options)
#     736 elif meth == 'cobyla':
# --> 737     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     738                            bounds=bounds, **options)
#     739 elif meth == 'cobyqa':
#     740     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     741                            **options)
#
# File ~/dev/qokit/lib/python3.10/site-packages/scipy/optimize/_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File ~/dev/qokit/lib/python3.10/site-packages/scipy/optimize/_cobyla_py.py:293, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     290         callback(np.copy(x))
#     292 info = np.zeros(4, np.float64)
# --> 293 xopt, info = cobyla.minimize(calcfc, m=m, x=np.copy(x0), rhobeg=rhobeg,
#     294                               rhoend=rhoend, iprint=iprint, maxfun=maxfun,
#     295                               dinfo=info, callback=wrapped_callback)
#     297 if info[3] > catol:
#     298     # Check constraint violation
#     299     info[0] = 4
#
# File ~/dev/qokit/lib/python3.10/site-packages/scipy/optimize/_cobyla_py.py:281, in _minimize_cobyla.<locals>.calcfc(x, con)
#     280 def calcfc(x, con):
# --> 281     f = sf.fun(x)
#     282     i = 0
#     283     for size, c in izip(cons_lengths, constraints):
#
# File ~/dev/qokit/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:325, in ScalarFunction.fun(self, x)
#     323 if not np.array_equal(x, self.x):
#     324     self._update_x(x)
# --> 325 self._update_fun()
#     326 return self.f
#
# File ~/dev/qokit/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:294, in ScalarFunction._update_fun(self)
#     292 def _update_fun(self):
#     293     if not self.f_updated:
# --> 294         fx = self._wrapped_fun(self.x)
#     295         if fx < self._lowest_f:
#     296             self._lowest_x = self.x
#
# File ~/dev/qokit/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:20, in _wrapper_fun.<locals>.wrapped(x)
#      16 ncalls[0] += 1
#      17 # Send a copy because the user may overwrite it.
#      18 # Overwriting results in undefined behaviour because
#      19 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 20 fx = fun(np.copy(x), *args)
#      21 # Make sure the function returns a true scalar
#      22 if not np.isscalar(fx):
#
# File ~/dev/QOKit/grips/QAOA_paper_proxy.py:87, in inverse_paper_proxy_objective_function.<locals>.inverse_objective(*args)
#      85 def inverse_objective(*args) -> float:
#      86     gamma, beta = args[0][:p], args[0][p:]
# ---> 87     _, expectation = QAOA_paper_proxy(p, gamma, beta, num_constraints, num_qubits)
#      88     current_time = time.time()
#      90     if expectations is not None:
#
# File ~/dev/QOKit/grips/QAOA_paper_proxy.py:73, in QAOA_paper_proxy(p, gamma, beta, num_constraints, num_qubits, terms_to_drop_in_expectation)
#      71 for current_depth in range(1, p + 1):
#      72     for cost_1 in range(num_costs):
# ---> 73         amplitude_proxies[current_depth][cost_1] = compute_amplitude_sum_paper(
#      74             amplitude_proxies[current_depth - 1], gamma[current_depth - 1], beta[current_depth - 1], cost_1, num_constraints, num_qubits
#      75         )
#      77 expected_proxy = 0
#      78 for cost in range(terms_to_drop_in_expectation, num_costs):
#
# File ~/dev/QOKit/grips/QAOA_paper_proxy.py:56, in compute_amplitude_sum_paper(prev_amplitudes, gamma, beta, cost_1, num_constraints, num_qubits)
#      54         beta_factor = (np.cos(beta) ** (num_qubits - distance)) * ((-1j * np.sin(beta)) ** distance)
#      55         gamma_factor = np.exp(-1j * gamma * cost_2)
# ---> 56         num_costs_at_distance = number_of_costs_at_distance_paper_proxy(cost_1, cost_2, distance, num_constraints, num_qubits)
#      57         sum += beta_factor * gamma_factor * prev_amplitudes[cost_2] * num_costs_at_distance
#      58 return sum
#
# File ~/dev/QOKit/grips/QAOA_paper_proxy.py:42, in number_of_costs_at_distance_paper_proxy(cost_1, cost_2, distance, num_constraints, num_qubits, prob_edge)
#      40 sum = 0
#      41 for common_constraints in range(max(0, cost_1 + cost_2 - num_constraints), min(cost_1, cost_2) + 1):
# ---> 42     sum += prob_common_at_distance_paper(num_constraints, num_qubits, common_constraints, cost_1, cost_2, distance)
#      44 p_cost = prob_cost_paper(cost_1, num_constraints, prob_edge)
#      45 return (math.comb(num_qubits, distance) / p_cost) * sum
#
# File ~/dev/QOKit/grips/QAOA_paper_proxy.py:31, in prob_common_at_distance_paper(num_constraints, num_qubits, common_constraints, cost_1, cost_2, distance)
#      29 prob_both = prob_neither
#      30 prob_one = (1 - prob_neither - prob_both) / 2
# ---> 31 return multinomial.pmf(
#      32     [common_constraints, cost_1 - common_constraints, cost_2 - common_constraints, num_constraints + common_constraints - (cost_1 + cost_2)],
#      33     num_constraints,
#      34     [prob_both, prob_one, prob_one, prob_neither],
#      35 )
#
# File ~/dev/qokit/lib/python3.10/site-packages/scipy/stats/_multivariate.py:3368, in multinomial_gen.pmf(self, x, n, p)
#    3350 def pmf(self, x, n, p):
#    3351     """Multinomial probability mass function.
#    3352
#    3353     Parameters
#    (...)
#    3366     %(_doc_callparams_note)s
#    3367     """
# -> 3368     return np.exp(self.logpmf(x, n, p))
#
# File ~/dev/qokit/lib/python3.10/site-packages/scipy/stats/_multivariate.py:3336, in multinomial_gen.logpmf(self, x, n, p)
#    3318 def logpmf(self, x, n, p):
#    3319     """Log of the Multinomial probability mass function.
#    3320
#    3321     Parameters
#    (...)
#    3334     %(_doc_callparams_note)s
#    3335     """
# -> 3336     n, p, npcond = self._process_parameters(n, p)
#    3337     x, xcond = self._process_quantiles(x, n, p)
#    3339     result = self._logpmf(x, n, p)
#
# File ~/dev/qokit/lib/python3.10/site-packages/scipy/stats/_multivariate.py:3271, in multinomial_gen._process_parameters(self, n, p, eps)
#    3268 p[i_adjusted, -1] = p_adjusted[i_adjusted]
#    3270 # true for bad p
# -> 3271 pcond = np.any(p < 0, axis=-1)
#    3272 pcond |= np.any(p > 1, axis=-1)
#    3274 n = np.array(n, dtype=int, copy=True)
#
# File <__array_function__ internals>:180, in any(*args, **kwargs)
#
# File ~/dev/qokit/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2307, in any(a, axis, out, keepdims, where)
#    2302 def _any_dispatcher(a, axis=None, out=None, keepdims=None, *,
#    2303                     where=np._NoValue):
#    2304     return (a, where, out)
# -> 2307 @array_function_dispatch(_any_dispatcher)
#    2308 def any(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#    2309     """
#    2310     Test whether any array element along a given axis evaluates to True.
#    2311
#    (...)
#    2395
#    2396     """
#    2397     return _wrapreduction(a, np.logical_or, 'any', axis, None, out,
#    2398                           keepdims=keepdims, where=where)
#
# KeyboardInterrupt:
